# %% [markdown]
# # Inflation
# General inflation-related calculations.

# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib widget

import wealth

wealth.inflation.inflation()
wealth.inflation.future_worth()
